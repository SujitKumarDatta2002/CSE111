# %% [markdown]
# **Task 01**

# %%
class Train():
    number = 0
    def __init__(self, *details) -> None:
        global det
        det = details
        print(f"Welcome aboard on {details[0]}\nStart: {details[1]}\nDestination: {details[-1]}")
        self.__route = list(details[1:])
        self.__passList = []
        Train.number += 1
    def addPassenger(self, *info):
        for i in info:
            pdict = {}
            pdict["Name"] = i.getName()
            pdict["Start"] = i.getStart()
            pdict["Destination"] = i.getDest()
            # fare = (self.__route.index(pdict["Destination"])-self.__route.index(pdict["Start"]))
            fare = self.__route.index(pdict["Destination"])-self.__route.index(pdict["Start"])
            pdict["Fair"] = "$" + str(fare*100)
            self.__passList.append(pdict)
            print(f"{i.getName()} welcome abroad")
    def allPassengerDetails(self):
        for j in self.__passList:
            passDetails = ""
            for key, val in j.items():
                passDetails += f"{key}: {val},"
            print(passDetails[:-1])

    @staticmethod
    def numberOfTrains():
        return Train.number

class Passenger():
    numberOf = 0
    def __init__(self, *passInfo) -> None:
        self.__name = passInfo[0]
        # self.start = None
        # self.dest = None
        Passenger.numberOf += 1
        if len(passInfo) == 1:
            self.__start = det[1]
            self.__dest = det[-1]
        elif len(passInfo) == 2:
            self.__start = passInfo[1]
            self.__dest = det[-1]
        else:
            self.__start = passInfo[1]
            self.__dest = passInfo[2]
    
    def setStart(self, start):
        self.__start = start
    
    def setDestination(self, dest):
        self.__dest = dest
    def getName(self):
         return self.__name
    def getStart(self):
         return self.__start
    def getDest(self):
         return self.__dest
    
    @staticmethod
    def numberOfPassenger():
        return Passenger.numberOf
    
    def setTravelDetails(self, s, d):
        self.__start = s
        self.__dest = d


t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
p1.setStart("New York")
p1.setDestination("Boston") 
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
print(Train.numberOfTrains())
print(Passenger.numberOfPassenger())
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max")
p5 = Passenger("Eleven")
p5.setTravelDetails("London","Brussels")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
print("6========================")
print(Train.numberOfTrains())
print(Passenger.numberOfPassenger())
#Welcome aboard on T1-Express
# Out:
# Welcome aboard on T1-Express
# Start: New York
# Destination: Boston
# 1========================
# Naruto welcome abroad
# 2========================
# Sasuke welcome abroad
# Hinata welcome abroad
# 3========================
# 1
# 3
# 3========================
# Name: Naruto,Start: New York,Destination: Boston,Fair: $300
# Name: Sasuke,Start: Manhattan,Destination: Boston,Fair: $200
# Name: Hinata,Start: Manhattan,Destination: Brooklyn,Fair: $100
# 4========================
# Welcome aboard on Europe-Express
# Start: London
# Destination: Turkey
# 5========================
# Max welcome abroad
# Eleven welcome abroad
# Mike welcome abroad
# 6========================
# Name: Max,Start: London,Destination: Turkey,Fair: $300
# Name: Eleven,Start: London,Destination: Brussels,Fair: $200
# Name: Mike,Start: Brussels,Destination: Turkey,Fair: $100
# 6========================
# 2
# 6

# %% [markdown]
# **Task 02**

# %%
class Student():
    def __init__(self, name, id, dept) -> None:
        self._name = name 
        self._id = id
        self._dept = dept
        self._email = None
        self._password = None
        self._course = []
        # self.status = None
        print("Student object is created!")

class Usis():
    def __init__(self) -> None:
        print("USIS is ready to use!")
        self.status = None
    def login(self, name):
        if name._email==None or name._password==None:
            print("Email and password need to be set.")
            self.status = False
        else:
            print("Login successful!")
            self.status = True
    def advising(self, *info):
        if self.status:
            if len(info) > 1:
                for i in range(1,len(info)):
                    info[0]._course.append(info[i])
            if len(info[0]._course) == 0:
                print("You haven't selected any courses.")
            elif len(info[0]._course) >= 4:
                print("You need special approval to take more than 3 courses.")
                info[0]._course = []
            else:
                print("Advising successful!")
        else:
            print("Please login to advise courses!")
    def individualDetails(self, obj):
        courses = ''
        for i in obj._course:
            courses += i +" ,"
        return f"Name: {obj._name}\nID: {obj._id}\nDepartment: {obj._dept}\nAdvised courses: {courses[:-1]}"



# Driver Code
rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib._email = "rakib@hotmail.com"
rakib._password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use!
# 2***********************
# Email and password need to be set.
# 3***********************
# Please login to advise courses!
# 4***********************
# 5***********************
# Login successful!
# 6***********************
# You haven't selected any courses.
# 7***********************
# You need special approval to take more than 3 courses.
# 8***********************
# Advising successful!
# 9***********************
# Name: Rakib
# ID: 12301455
# Department: CSE
# Advised courses: CSE110 ,PHY111 ,MAT110

# %% [markdown]
# **Task 03**

# %%
from math import pi


class Cylinder:
    numberOfCylinder = 0
    radius = 5
    height = 18

    def __init__(self, radius, height):

        print(f"Default radius = {Cylinder.radius} and height = {Cylinder.height}.")

        Cylinder.radius = radius
        Cylinder.height = height
        Cylinder.numberOfCylinder += 1

        print(f"Updated: radius = {Cylinder.radius} and height = {Cylinder.height}.")

    @classmethod
    def swap(cls, height, radius):
        return cls(radius, height)

    @classmethod
    def changeFormat(cls, info_str):
        radius, height = info_str.split("-")
        radius = float(radius)
        height = float(height)
        return cls(radius, height)

    @staticmethod
    def area(radius, height):
        area = 2 * pi * (radius ** 2) + 2 * pi * radius * height
        print(f"Area: {area}")

    @staticmethod
    def volume(radius, height):
        volume = pi * (radius ** 2) * height
        print(f"Volume: {volume}")





# Write your code here
    
c1 = Cylinder(0,0)
Cylinder.area(c1.radius,c1.height)
Cylinder.volume(c1.radius,c1.height)
print("===============================")
c2 = Cylinder.swap(8,3)
c2.area(c2.radius,c2.height)
c2.volume(c2.radius,c2.height)
print("===============================")
print(Cylinder.numberOfCylinder)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius,c3.height)
c3.volume(c3.radius,c3.height)
print("===============================")
Cylinder(0.3,5.56).area(Cylinder.radius,Cylinder.height)
print("===============================")
Cylinder(3,5).volume(Cylinder.radius,Cylinder.height)
print("===============================")
print(Cylinder.numberOfCylinder)
# Out:
# Default radius = 5 and height = 18.
# Updated: radius = 0 and height = 0.
# Area: 0.0
# Volume: 0.0
# ...
# Default radius = 0 and height = 0.
# Updated: radius = 3 and height = 8.
# Area: 207.34511513692635
# Volume: 226.1946710584651
# ...
# 2
# ...
# Default radius = 3 and height = 8.
# Updated: radius = 7.0 and height = 13.0.
# Area: 879.645943005142
# Volume: 2001.1945203366981
# ...
# Default radius = 7.0 and height = 13.0.
# Updated: radius = 0.3 and height = 5.56.
# Area: 11.045839770021713
# ...
# Default radius = 0.3 and height = 5.56.
# Updated: radius = 3 and height = 5.
# Volume: 141.3716694115407
# ...
# 5

# %% [markdown]
# **Task 04**

# %%
class Student():
    totalStudent = 0
    cseStudent = 0
    bbaStudent = 0

    def __init__(self, name, dept) -> None:
        self.name = name 
        self.dept = dept
        Student.totalStudent += 1

        if self.dept == 'CSE':
            Student.cseStudent += 1
        else:
            Student.bbaStudent += 1

        print(f"Creating Student Number: {Student.totalStudent}")

    def individualInfo(self):
        print(f"{self.name} is from {self.dept} department.")
        print(f"Serial of {self.name} among all students' is: {Student.totalStudent}")
        if self.dept == 'CSE':
            print(f"Serial of {self.name} in CSE department is: {Student.cseStudent}")
        else:
            print(f"Serial of {self.name} in BBA department is: {Student.bbaStudent}")

    def totalInfo(self):
        print(f"Total Number of Student: {Student.totalStudent}")
        print(f"Total Number of CSE Student: {Student.cseStudent}")
        print(f"Total Number of BBA Student: {Student.bbaStudent}")

# Write Your Code Here


s1 = Student("Naruto", "CSE")
print('----------------------')
s1.individualInfo()
print('#############################')
s1.totalInfo()
print('============================')


s2 = Student("Sakura", "BBA")
print('----------------------')
s2.individualInfo()
print('#############################')
s2.totalInfo()
print('============================')


s3 = Student("Shikamaru", "CSE")
print('----------------------')
s3.individualInfo()
print('#############################')
s3.totalInfo()
print('============================')


s4 = Student("Deidara", "BBA")
print('----------------------')
s4.individualInfo()
print('#############################')
s4.totalInfo()
# Out:
# Creating Student Number: 1
# ----------------------
# Naruto is from CSE department.
# Serial of Naruto among all students' is: 1
# Serial of Naruto in CSE department is: 1
# #############################
# Total Number of Student: 1
# Total Number of CSE Student: 1
# Total Number of BBA Student: 0
# ...
# Creating Student Number: 2
# ----------------------
# Sakura is from BBA department.
# Serial of Sakura among all students' is: 2
# Serial of Sakura in BBA department is: 1
# #############################
# Total Number of Student: 2
# Total Number of CSE Student: 1
# Total Number of BBA Student: 1
# ...
# Creating Student Number: 3
# ----------------------
# Shikamaru is from CSE department.
# Serial of Shikamaru among all students' is: 3
# Serial of Shikamaru in CSE department is: 2
# #############################
# Total Number of Student: 3
# Total Number of CSE Student: 2
# Total Number of BBA Student: 1
# ...
# Creating Student Number: 4
# ----------------------
# ...

# %% [markdown]
# **Task 05**

# %%
class FinalT6A:
    temp,y = 3,2
 
    def __init__(self, x=3, p=1):
        self.sum = self.temp
        self.temp += 3
        self.y = self.y - p
        self.sum = self.temp + x
        print(x, self.y, self.sum)
    
    def methodA(self):
        x, y, temp = 0, 0, 2
        y = y + self.y
        x = self.y + 2 + temp
        self.sum = x +  FinalT6A().methodB(temp, x) + self.methodB(self.temp, y)
        print(x, y, self.sum)
    
    def methodB(self, temp, n):
        x = 0
        FinalT6A.y += 1
        self.y = self.y + (FinalT6A.y)
        FinalT6A.temp -= 1
        x = x + 2 + n
        self.sum = self.sum + x + self.y
        print(x, self.y, self.sum)
        return self.sum

q1 = FinalT6A(2,1)
q1.methodA()
q1.methodA()
# Out:
# 2 1 8
# 3 1 9
# 7 4 20
# 3 5 16
# 5 1 41
# 3 3 7
# 11 8 26
# 7 11 59
# 9 5 94

# %% [markdown]
# **Task 06**

# %%
class Quiz1:
    temp = 4


    def __init__(self, p = None):
        if p is None:
            self.y = self.temp - 1
            self.sum = self.temp + 1
            Quiz1.temp += 2
        else:
            self.y = self.temp + p
            self.sum = p + self.temp + 1
            Quiz1.temp -= 1
    
    def methodA(self):
        x, y = 0, 0
        y = y + self.y
        x = self.y + 2 + self.temp
        self.sum = x + y + self.methodB(x, y)
        print(x, y, self.sum)
    
    def methodB(self, m, n):
        x = 0
        Quiz1.temp += 1
        self.y = self.y + m + (self.temp)
        x = x + 2 + n
        self.sum = self.sum + x + self.y
        print(x, self.y, self.sum)
        return self.sum
# Consider the following code:

q1 = Quiz1()
q1.methodA()
q1.methodA()
Quiz1.temp += 2
q2 = Quiz1(2)
q2.methodA()
q2.methodA()
# Out:
# 5 21 31
# 11 3 45
# 23 59 127
# 30 21 178
# 14 45 72
# 23 12 107
# 47 113 267
# 57 45 369

# %% [markdown]
# **Task 07**

# %%
class A:
    temp = 4
    def __init__(self):
        self.y = self.temp - 2
        self.sum = self.temp + 1
        A.temp -= 2
        self.methodA(3, 4)
    def methodA(self, m, n):
        x = 0
        self.y = self.y + m + (self.temp)
        A.temp += 1
        x = x + 1 + n
        self.sum = self.sum + x + self.y
        print(x, self.y, self.sum)
    
class B:
    x = 0
    def __init__(self, b = None):
        self.y, self.temp, self.sum = 5, -5, 2
 
        if b == None:
            self.y = self.temp + 3
            self.sum = 3 + self.temp + 2
            self.temp -= 2
        else:
            self.sum = b.sum
            B.x = b.x
            b.methodB(2, 3)
    def methodA(self, m, n):
        x = 2
        self.y = self.y + m + (self.temp)
        self.temp += 1
        x = x + 5 + n
        self.sum = self.sum + x + self.y
        print(x, self.y, self.sum)
    def methodB(self, m, n):
        y = 0
        y = y + self.y
        B.x = self.y + 2 + self.temp
        self.methodA(self.x, y)
        self.sum = self.x + y + self.sum
        print(self.x, y, self.sum)


a1 = A()
b1 = B()
b2 = B(b1)
b1.methodA(1, 2)
b2.methodB(3, 2)
# Out:
# 5 -16 -11
# -7 -2 -20
# 9 -21 -32
# 12 2 14
# 2 5 21
